# %%
'''
****************************
* master file for FFAT analysis of proteomes
* simple arrangement
* - select 'live' files - ie true proteomes, or test ones.
* - select the particular file(s) for test
* - select the particular analysis required.
*
* as analyses and files are added these are catered for in the modules called here
* so I see little substantial change here
* 15 Sep 2018
*
* here is the full (current structure)
* lists of available files are kept in the following two files:
* - proteomes.txt = 'live' versions
* - proteomes_test_files.txt = test versions
* Proteome Core file contains the class ProteomeReader for retrieving the files into a standard format
*   and also contains ProteomeActivityLogger to keep track of what happened when
* Proteome Scorer contains class SequenceAnalysis which does the basic work on the protein amino acid sequences
* Proteome Analyser contains ProteomeAnalyser which does the high level analysis
* this module allows with the user to specify what files are to be analysed, and retrieves the proteomes, 
*   and then allows the user to specify the analysis, It then passes the proteomes 
*   into ProteomeAnalyser for the specified analysis to take place
*
* Proteome Test Harness runs specific functional and full regression tests
*
* 29 Dec 2018
* extra functionality both here and in Proteome Analyser
* following request to add ability to add generation of proteome files and top ten for randomised proteomes
****************************
'''

'''
* - select the individual files to run - prod or test.
* - normally should be core release versions
'''

#%run 'Proteome Core Release.ipynb'
# %run 'Proteome Core Dev.ipynb'
# %run 'Proteome Scorer Dev.ipynb'
# %run 'Proteome Analyser Dev.ipynb'

def getnumberlist(strnos):
    if '-' in strnos:
        idx = strnos.index('-')
        int1 = int(strnos[ : idx])
        int2 = int(strnos[idx + 1:])
        return range(int1, int2 + 1)
    else:
        return map(int, strnos.split())
    
def RunAnalysis():
    
    bexit = False
    bprintmode = True
    bhavetestlogger = False
    bhaveprodlogger = False
    
    while not bexit:
        
        itestmode = int(raw_input('Enter 0 for live or 1 for test (anything else exits) '))

        if itestmode == 0:
            btestmode = False
            if not bhaveprodlogger:
                livelogger = ProteomeActivityLogger(btestmode, bprintmode)
                bhaveprodlogger = True
        elif itestmode == 1:
            btestmode = True
            if not bhavetestlogger:
                testlogger = ProteomeActivityLogger(btestmode, bprintmode)
                bhavetestlogger = True
        else:
            bexit = True

        if not bexit:
            
            if btestmode:
                mylogger = testlogger
            else:
                mylogger = livelogger

            myreader = ProteomeReader(btestmode)
            myscorer = SequenceAnalysis()
            myanalysis = ProteomeAnalyser(mylogger, myscorer, btestmode)
            
            print 'reader version = ' + myreader.versionid
            print 'scorer version = ' + myscorer.versionid
            print 'analyser version = ' + myanalysis.versionid

            mylogger.write_log_entry('core reader version = ' + myreader.versionid)

            print 'available files'
            print '---------------'
            availablefiles = myreader.showlibrary()
            for i in range(0, len(availablefiles)):
                print i, availablefiles[i][0]

            print ' '
            fn = raw_input('enter files to test (no commas) ')
            myfilenos = getnumberlist(fn)
            #myfilenos =  map(int, fn.split())

            availableanalyses = myanalysis.available_analysis()
            print ' '
            print 'available analyses'
            print '---------------'
            for i in range(0, len(availableanalyses)):
                print i, availableanalyses[i][1], availableanalyses[i][2]

            idx = int(raw_input('Enter analysis to test '))
            print ' '
            
            bfullproteome = False # need as now an argument of run_analysis for some options
            if myanalysis.has_generatedproteome_option(idx):
                bfullproteome = (1 == int(raw_input('Enter 1 for full proteome file generation, anything else for just a histogram ')))

            myproteomes = myreader.read_files(myfilenos)

            myanalysis.run_analysis(idx, myproteomes, bfullproteome)
            

            print ' '
            print 'finished analysis'
            print ' '

       
    print 'terminated'
        
'''
****************************
* run RunAnalysis for a directed route to analysis
****************************
'''

RunAnalysis()
# Out:
# Enter 0 for live or 1 for test (anything else exits) 0
# New activity log version 1.2 Candidate release **
# 0: 20190214 19:27. scorer version = Dev on 1.0, logger version = Dev on 1.0
# 1: 20190214 19:27. random seed set to 1550172476
# reader version = 1.1 Candidate release
# scorer version = Dev on 1.0
# analyser version = Dev on 1.0
# 2: 20190214 19:27. core reader version = 1.1 Candidate release
# available files
# ---------------
# 0 orf_trans
# 1 uniprot_proteome_yeastx6049_fasta
# 2 HumanProteomeFasta
# 3 Plasmodium_3D7_proteome_fasta
# 4 Albugo_proteome_fasta
# 5 uniprot_Arabidopsis_proteome_fasta
# 6 uniprot_C_elegans_proteome_fasta
# 7 uniprot_Drosophila_proteome_fasta
# 8 UP000025675_M_tuberculosis_proteome_x3978_fasta
# 9 UP000008816_S_aureus_x2889_fasta
# 10 UP000051952_Bodo_saltans_x18124_fasta
# 11 UP000009168_Tetrahymena_proteome_x26976_fasta
# 12 Ubr1x1331 ipr003126(NOTpf02617pf13764pf12937+ident05fasta
# 13 Rqc1=Tcf25x545identity05fasta
# 14 Mcm3x196identity05fasta
# 15 Seg2_blits3_x23
# 16 Spironucleus_proteome_AUP000018208fasta
# 17 Ecoli_proteome_AUP000000625fasta
# 18 Giardia_proteome_AUP000001548fasta
# 19 Mycoplasma_proteome_AUP000239951fasta
# 20 uniprot-proteome_Angomonas_deanei_fasta
# 21 uniprotproteome_Haloterrigena_turkmenica_Archea_fasta
# 22 Kri1spf05178pf12936identity05
# 23 Bbc1smti1identity05
# 24 YPR097Wspf12828+pf12825+identity05
# 25 YLR149Cspf10313+ipr015943+identity05
# 26 RFIPsallfip+rbd+identity05
# 27 Ede1x224_uniref_uniprot3A28uba+22eh+dom2229fasta
# 28 FormatSeq_HALTV727b3_x615v2
# 29 FormatSeq_HALTV299b_x135v2
# 30 FormatSeq_HALTV265b3_x245v2
# 31 E_histolyticaATCC30459_7959fasta
# 32 VPS13chorein_Nvps13_atg2_caduniref50x3867fasta
# 33 Erb1OrthoDBEOG093704ZYx537_506_species
# 34 Opi1OrthoDBx200 fungiEOG092C5A9Y
# 35 Ost1OrthDBx353EOG091G05K5
# 36 Rnf31uniref50x343ex833fasta
# 37 Sfb3_uniref50x488fasta
# 38 Asg7x29fromOrthoDBfasta
# 39 ACBD5_proteins
# 40 ACBP_superfamily_proteins
# 41 uniprot_proteome_AUP000001974_Sulfolobus_solfataricusx2938_fasta
# 42 uniprot_proteome_AUP000002199_Archaeoglobus_fulgidusx2399_fasta
# 43 uniprot_proteome_AUP000000805_Methanocaldococcus_jannaschiix1732_fasta
# 44 uniprot_proteome_AUP000000595_Methanosarcina_mazeix3303_fasta
# 45 uniprot_proteome_AUP000000752_Pyrococcus_horikoshiix2077_fasta
# 46 uniprot-proteome_AUP000001024_Thermoplasma acidophilumx1482_fasta
# 47 proteome_Perkinsela_fasta
# 48 proteome_Paratrypanosoma_confusum_fasta
# 49 proteome_Euglena_gracilis_fasta
# 50 Phytomonas_Hart1_AUP000053358_fasta
# 51 Phytomonas_EM1_AUP000027080_fasta
# 52 Leptomonas_seymouri_AUP000038009_fasta
# 53 Strigomonas_AUP000015354_fasta
# 54 Trypanosoma_equiperdum_AUP000195570_fasta
# 55 proteome_08076_E_dispar_fasta
# 56 proteome_014680_E_invadens_fasta
# 57 proteome_06769_E_nuttalli_fasta
# 58 Vps13_Amoebozoa_167
# 59 uniref-uniprot_UBR4_OR_pf13764_507fasta
# 60 Ubr1_eog092c01d2_nr90
# 61 Vid27_EOG092C1KQX_nr90
# 62 Osh3_eog092c0t4h_nr90
# 63 Exo1_eog092c2bju_nr90
# 64 Kri1_EOG092C3V2Y_nr90
# 65 Ost1_EOG092C29MC_nr90
# 66 Ede1_EOG092C055E_nr90
# 67 Bbc1_EOG092C0BBJ_nr90
# 68 Opi1_EOG092C5A9Y_nr90
# 69 YPR097W_eog092c0e1b_nr90
# 70 OSH2_eog092c0gj4_nr90
# 71 ERB1_EOG092C1381_nr90
# 72 ASG7_eog092c5rpj_nr90
# 73 NOP2_EOG092C2BNS
# 74 SKP2_EOG092C0MR8
# 75 STE13_EOG092C0PZJ
# 76 UBP10_EOG092C5R71
# 77 MCM3_EOG092C0VUM
# 78 WSC2_EOG092C5SG6
# 79 SFB3_EOG092C0DKG
# 80 PET123_EOG092C4SPI
# 81 RQC1_EOG092C0TUL
# 82 YOR238W_EOG092C3RPQ
# 83 Kar2_EOG092C1VPN
# 84 Ylr149c_EOG092C28
# 85 TUB1_EOG092C2JRV
# 86 NOP2_EOG091G0685
# 87 ACS1_EOG092C0Z1N
# 88 ECM13_EOG092C4UTV
# 89 EFR3_EOG092C0OH2
# 90 ENT3_EOG092C3ZA8
# 91 MET4_EOG092C5FM7
# 92 MGR3_EOG092C3NE2
# 93 MSH6_EOG092C0EWT
# 94 RKR1_EOG092C029X
# 95 SXM1_EOG092C0CGO
# 96 YHL026C_EOG092C2HBH
# 97 AIM44_EOG092C5FAO
# 98 DYN1_EOG092C00NZ
# 99 EPO1_EOG092C0XF3
# 100 KXD1_EOG092C5F1D
# 101 MDV1_EOG092C172M
# 102 MGA2_EOG092C06NJ
# 103 NUM1_EOG092C01BH
# 104 PBI1_EOG092C41LE
# 105 SEC2_EOG092C3RPI
# 106 SEC27_EOG092C10HM
# 107 SEC63_EOG092C20BT
# 108 SEC66_EOG092C58AK
# 109 TOR1_EOG092C00HJ
# 110 UBP1_EOG092C3TMU
# 111 UBP2_EOG092C04TL
# 112 VPS13_EOG092C0SXB
# 113 YJL049W_EOG092C3Z1D
# 114 YML003W_EOG092C00HJ
# 115 YML002W_EOG092C087J
# 116 YPT7_EOG092C5MDH
# 117 YPT7_FUNGALx38
# 118 EDE1muc_EOG092C055E
# 119 Eps15_homologues391
# 120 Opi1_blastx101
# 121 Kri1_pfx2nr90_metazoa_x226
# 122 Erb1_BOP1NT_NOT_EOG092C1381x904
# 123 MCM3_28266497at2759_metazoa_nr50
# 124 MCM3_28266497at2759_metazoa_nr90
# 125 NOP2_plants_nr90
# 126 Sec24C_nonfungi_nr90
# 127 Sec24ABD_nonfungi_nr90
# 128 TUBA_nonfungi_nr90
# 129 Tcf25_metazoa_nr90
# 130 Tcf25_viridiplantae_nr90
# 131 Efr3_viridiplantae_nr90
# 132 Efr3_metazoa_nr90
# 133 Sxm1_all_nr90
# 134 Msh6_Nterms
# 135 Irr1_fungi_nr90
# 136 Irr1_metazoa_nr90
# 137 Vps13_Fungal_select_nr90
# 138 CHMP7_all_nr90
# 139 Kxd1_all_nr90
# 140 Sec2_all_nr90
# 141 bNOP2_nr50_n650_POG091H02E2
# 142 KRI1_pfx2nr90_NOTmetazoa_x672
# 143 USP36_all_nr90
# 144 Vid27_domain_nonF_nr90
# 145 Vid27_name_nonF_nr90
# 146 Epsin_all_nr90
# 147 Kri1_viridiplantae_nr90_x79
# 148 Epsin_plants_nr90
# 149 MSH6_nonFungi_nr50
#
# enter files to test (no commas) 148 149
#
# available analyses
# ---------------
# 0 Proteome Score Creates a csv file with a full list of FFAT scores for each protein
# 1 Bottom Ten Creates a csv file the lowest 10 scores for each protein plus location
# 2 Bottom Ten - Sorted Creates a csv file the lowest 10 scores for each protein, sorted by lowest score. Very slow
# 3 Histogram Creates a csv file of a histogram of the FFAT scores of a proteome
# 4 Histogram + randomised histogram (full proteome) a histogram of the FFAT scores of a proteome plus a randomised equivalent histogram (by full proteome)
# 5 Histogram + randomised histogram (within protein) as 4, but randomised within protein
# 6 Reordered Histogram a histogram of the FFAT scores of a proteome plus a reordered weighting equivalent histogram
# 7 Histogram + randomised preserving acids (full proteome) score = 0.5 a histogram of the FFAT scores of a proteome plus a randomised equivalent preserving acids in low-scoring flanks score = 0.5
# 8 Histogram + randomised preserving acids (within protein) score = 0.5 as 7, but randomised within protein
# 9 Histogram + randomised preserving acids (full proteome) score = 0.0 a histogram of the FFAT scores of a proteome plus a randomised equivalent preserving acids in low-scoring flanks
# 10 Histogram + randomised preserving acids (within protein) score = 0.0 as 7, but randomised within protein
# Enter analysis to test 2
#
# 3: 20190214 19:28. running bottom_ten_sorted on proteome Epsin_plants_nr90
# 4: 20190214 19:28. finished sorted and ranking proteins in Epsin_plants_nr90
# 5: 20190214 19:28. running bottom_ten_sorted on proteome MSH6_nonFungi_nr50
# 6: 20190214 19:28. finished sorted and ranking proteins in MSH6_nonFungi_nr50
# 7: 20190214 19:28. finished bottom ten - sorted
#
# finished analysis
#
# Enter 0 for live or 1 for test (anything else exits) 0
# 8: 20190214 19:28. scorer version = Dev on 1.0, logger version = Dev on 1.0
# 9: 20190214 19:28. random seed set to 1550172537
# reader version = 1.1 Candidate release
# scorer version = Dev on 1.0
# analyser version = Dev on 1.0
# 10: 20190214 19:28. core reader version = 1.1 Candidate release
# available files
# ---------------
# 0 orf_trans
# 1 uniprot_proteome_yeastx6049_fasta
# 2 HumanProteomeFasta
# 3 Plasmodium_3D7_proteome_fasta
# 4 Albugo_proteome_fasta
# 5 uniprot_Arabidopsis_proteome_fasta
# 6 uniprot_C_elegans_proteome_fasta
# 7 uniprot_Drosophila_proteome_fasta
# 8 UP000025675_M_tuberculosis_proteome_x3978_fasta
# 9 UP000008816_S_aureus_x2889_fasta
# 10 UP000051952_Bodo_saltans_x18124_fasta
# 11 UP000009168_Tetrahymena_proteome_x26976_fasta
# 12 Ubr1x1331 ipr003126(NOTpf02617pf13764pf12937+ident05fasta
# 13 Rqc1=Tcf25x545identity05fasta
# 14 Mcm3x196identity05fasta
# 15 Seg2_blits3_x23
# 16 Spironucleus_proteome_AUP000018208fasta
# 17 Ecoli_proteome_AUP000000625fasta
# 18 Giardia_proteome_AUP000001548fasta
# 19 Mycoplasma_proteome_AUP000239951fasta
# 20 uniprot-proteome_Angomonas_deanei_fasta
# 21 uniprotproteome_Haloterrigena_turkmenica_Archea_fasta
# 22 Kri1spf05178pf12936identity05
# 23 Bbc1smti1identity05
# 24 YPR097Wspf12828+pf12825+identity05
# 25 YLR149Cspf10313+ipr015943+identity05
# 26 RFIPsallfip+rbd+identity05
# 27 Ede1x224_uniref_uniprot3A28uba+22eh+dom2229fasta
# 28 FormatSeq_HALTV727b3_x615v2
# 29 FormatSeq_HALTV299b_x135v2
# 30 FormatSeq_HALTV265b3_x245v2
# 31 E_histolyticaATCC30459_7959fasta
# 32 VPS13chorein_Nvps13_atg2_caduniref50x3867fasta
# 33 Erb1OrthoDBEOG093704ZYx537_506_species
# 34 Opi1OrthoDBx200 fungiEOG092C5A9Y
# 35 Ost1OrthDBx353EOG091G05K5
# 36 Rnf31uniref50x343ex833fasta
# 37 Sfb3_uniref50x488fasta
# 38 Asg7x29fromOrthoDBfasta
# 39 ACBD5_proteins
# 40 ACBP_superfamily_proteins
# 41 uniprot_proteome_AUP000001974_Sulfolobus_solfataricusx2938_fasta
# 42 uniprot_proteome_AUP000002199_Archaeoglobus_fulgidusx2399_fasta
# 43 uniprot_proteome_AUP000000805_Methanocaldococcus_jannaschiix1732_fasta
# 44 uniprot_proteome_AUP000000595_Methanosarcina_mazeix3303_fasta
# 45 uniprot_proteome_AUP000000752_Pyrococcus_horikoshiix2077_fasta
# 46 uniprot-proteome_AUP000001024_Thermoplasma acidophilumx1482_fasta
# 47 proteome_Perkinsela_fasta
# 48 proteome_Paratrypanosoma_confusum_fasta
# 49 proteome_Euglena_gracilis_fasta
# 50 Phytomonas_Hart1_AUP000053358_fasta
# 51 Phytomonas_EM1_AUP000027080_fasta
# 52 Leptomonas_seymouri_AUP000038009_fasta
# 53 Strigomonas_AUP000015354_fasta
# 54 Trypanosoma_equiperdum_AUP000195570_fasta
# 55 proteome_08076_E_dispar_fasta
# 56 proteome_014680_E_invadens_fasta
# 57 proteome_06769_E_nuttalli_fasta
# 58 Vps13_Amoebozoa_167
# 59 uniref-uniprot_UBR4_OR_pf13764_507fasta
# 60 Ubr1_eog092c01d2_nr90
# 61 Vid27_EOG092C1KQX_nr90
# 62 Osh3_eog092c0t4h_nr90
# 63 Exo1_eog092c2bju_nr90
# 64 Kri1_EOG092C3V2Y_nr90
# 65 Ost1_EOG092C29MC_nr90
# 66 Ede1_EOG092C055E_nr90
# 67 Bbc1_EOG092C0BBJ_nr90
# 68 Opi1_EOG092C5A9Y_nr90
# 69 YPR097W_eog092c0e1b_nr90
# 70 OSH2_eog092c0gj4_nr90
# 71 ERB1_EOG092C1381_nr90
# 72 ASG7_eog092c5rpj_nr90
# 73 NOP2_EOG092C2BNS
# 74 SKP2_EOG092C0MR8
# 75 STE13_EOG092C0PZJ
# 76 UBP10_EOG092C5R71
# 77 MCM3_EOG092C0VUM
# 78 WSC2_EOG092C5SG6
# 79 SFB3_EOG092C0DKG
# 80 PET123_EOG092C4SPI
# 81 RQC1_EOG092C0TUL
# 82 YOR238W_EOG092C3RPQ
# 83 Kar2_EOG092C1VPN
# 84 Ylr149c_EOG092C28
# 85 TUB1_EOG092C2JRV
# 86 NOP2_EOG091G0685
# 87 ACS1_EOG092C0Z1N
# 88 ECM13_EOG092C4UTV
# 89 EFR3_EOG092C0OH2
# 90 ENT3_EOG092C3ZA8
# 91 MET4_EOG092C5FM7
# 92 MGR3_EOG092C3NE2
# 93 MSH6_EOG092C0EWT
# 94 RKR1_EOG092C029X
# 95 SXM1_EOG092C0CGO
# 96 YHL026C_EOG092C2HBH
# 97 AIM44_EOG092C5FAO
# 98 DYN1_EOG092C00NZ
# 99 EPO1_EOG092C0XF3
# 100 KXD1_EOG092C5F1D
# 101 MDV1_EOG092C172M
# 102 MGA2_EOG092C06NJ
# 103 NUM1_EOG092C01BH
# 104 PBI1_EOG092C41LE
# 105 SEC2_EOG092C3RPI
# 106 SEC27_EOG092C10HM
# 107 SEC63_EOG092C20BT
# 108 SEC66_EOG092C58AK
# 109 TOR1_EOG092C00HJ
# 110 UBP1_EOG092C3TMU
# 111 UBP2_EOG092C04TL
# 112 VPS13_EOG092C0SXB
# 113 YJL049W_EOG092C3Z1D
# 114 YML003W_EOG092C00HJ
# 115 YML002W_EOG092C087J
# 116 YPT7_EOG092C5MDH
# 117 YPT7_FUNGALx38
# 118 EDE1muc_EOG092C055E
# 119 Eps15_homologues391
# 120 Opi1_blastx101
# 121 Kri1_pfx2nr90_metazoa_x226
# 122 Erb1_BOP1NT_NOT_EOG092C1381x904
# 123 MCM3_28266497at2759_metazoa_nr50
# 124 MCM3_28266497at2759_metazoa_nr90
# 125 NOP2_plants_nr90
# 126 Sec24C_nonfungi_nr90
# 127 Sec24ABD_nonfungi_nr90
# 128 TUBA_nonfungi_nr90
# 129 Tcf25_metazoa_nr90
# 130 Tcf25_viridiplantae_nr90
# 131 Efr3_viridiplantae_nr90
# 132 Efr3_metazoa_nr90
# 133 Sxm1_all_nr90
# 134 Msh6_Nterms
# 135 Irr1_fungi_nr90
# 136 Irr1_metazoa_nr90
# 137 Vps13_Fungal_select_nr90
# 138 CHMP7_all_nr90
# 139 Kxd1_all_nr90
# 140 Sec2_all_nr90
# 141 bNOP2_nr50_n650_POG091H02E2
# 142 KRI1_pfx2nr90_NOTmetazoa_x672
# 143 USP36_all_nr90
# 144 Vid27_domain_nonF_nr90
# 145 Vid27_name_nonF_nr90
# 146 Epsin_all_nr90
# 147 Kri1_viridiplantae_nr90_x79
# 148 Epsin_plants_nr90
# 149 MSH6_nonFungi_nr50
#
# enter files to test (no commas) 148 149
#
# available analyses
# ---------------
# 0 Proteome Score Creates a csv file with a full list of FFAT scores for each protein
# 1 Bottom Ten Creates a csv file the lowest 10 scores for each protein plus location
# 2 Bottom Ten - Sorted Creates a csv file the lowest 10 scores for each protein, sorted by lowest score. Very slow
# 3 Histogram Creates a csv file of a histogram of the FFAT scores of a proteome
# 4 Histogram + randomised histogram (full proteome) a histogram of the FFAT scores of a proteome plus a randomised equivalent histogram (by full proteome)
# 5 Histogram + randomised histogram (within protein) as 4, but randomised within protein
# 6 Reordered Histogram a histogram of the FFAT scores of a proteome plus a reordered weighting equivalent histogram
# 7 Histogram + randomised preserving acids (full proteome) score = 0.5 a histogram of the FFAT scores of a proteome plus a randomised equivalent preserving acids in low-scoring flanks score = 0.5
# 8 Histogram + randomised preserving acids (within protein) score = 0.5 as 7, but randomised within protein
# 9 Histogram + randomised preserving acids (full proteome) score = 0.0 a histogram of the FFAT scores of a proteome plus a randomised equivalent preserving acids in low-scoring flanks
# 10 Histogram + randomised preserving acids (within protein) score = 0.0 as 7, but randomised within protein
# Enter analysis to test 5
#
# Enter 1 for full proteome file generation, anything else for just a histogram 99
# 11: 20190214 19:29. running histogram_fully_randomised on proteome Epsin_plants_nr90
# 12: 20190214 19:29. seed = 1
# 13: 20190214 19:29. running histogram_fully_randomised on proteome MSH6_nonFungi_nr50
# 14: 20190214 19:29. seed = 1
#
# finished analysis
#
# Enter 0 for live or 1 for test (anything else exits) 99
# terminated
